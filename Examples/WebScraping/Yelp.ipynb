# %%
# YouTube = https://youtu.be/iqWZQcW5FTE

import requests as r
from bs4 import BeautifulSoup as soup

# %%
url = 'https://www.yelp.com/biz/taco-bell-los-angeles-24'

# %%
data = r.get(url)
data                # Check to see if connected
# Out:
# <Response [200]>

# %%
page_data = soup(data.text, 'html.parser')
# page_data

# %%
print(page_data.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script nonce="247370f7">
#             (function() {
#                 var main = null;
#
# ...

# %%
soup_data = page_data.find_all('ul', {'class': 'lemon--ul__373c0__1_cxs undefined list__373c0__2G8oH'})

# %%
soup_data[0].find('p').text
# Out:
# 'Due to ongoing precautionary measures, please contact the business directly for updated hours and availability.'

# %%
aa

# %%
data = r.get(url)
data # Checks if you made a connection
# Out:
# <Response [200]>

# %%
aaa

# %%
a
